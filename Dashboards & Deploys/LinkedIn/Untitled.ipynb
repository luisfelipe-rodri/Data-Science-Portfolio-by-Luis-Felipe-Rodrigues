# %%
import pandas as pd
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %%
df = pd.read_csv("Connections.csv", sep=',', encoding='utf-8')

# %%
df.head(30)
# Out:
#                                            First Name             Last Name  \
# 0                                              Calvin             de Wilde🍜
# 1                                               Sofia  Marshallowitz Apuzzo
# 2                                         Maria Luíza   Tolentino de Araujo
# 3                                               André                Sigora
# 4                                               Livia             Sacchetti
# 5                                     Bruna Christina           Battissacco
# 6                                              Donato               Rimenti
# 7                                                Dino              Esposito
# 8                                        Jose Tenorio            Abs Junior
# 9   Alexandre,"Bernier, CFA",,Plotly,Vice Presiden...                   NaN
# 10                                             Victor               Feitosa
# 11  Will,"DeMarest, MSc, MBA",,Tuft & Needle (Sert...                   NaN
# 12                                          Maristela           Albuquerque
# 13                                         João Marco        Braga da Cunha
# 14                                              Diego              Botassio
# 15                                              Pedro               Scharth
# 16                                               Luiz               Esteves
# 17                                             Camila              Takahira
# 18                                             Renato               Conchon
# 19                                           Jeronymo             marcondes
# 20                                          Ivanilson  Aparecido Nascimento
# 21                                             Felipe             Alvarenga
# 22                                             Renata           Albuquerque
# 23                                             Amanda                 Lopes
# 24                                           Frédéric         Lefebvre-Naré
# 25                                            Monique                Evelle
# 26                                          Guilherme             Lissandre
# 27                                           Henrique                Comaru
# 28                                         Alessandra               Montini
# 29                                             Shahab           Anbarjafari
#
#                    Email Address  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# 5                            NaN
# 6                            NaN
# 7                            NaN
# 8                            NaN
# 9                            NaN
# 10                           NaN
# 11                           NaN
# 12                           NaN
# 13                           NaN
# 14                           NaN
# 15                           NaN
# 16                           NaN
# 17                           NaN
# 18                           NaN
# 19                           NaN
# 20                           NaN
# 21                           NaN
# 22                           NaN
# 23                           NaN
# 24                           NaN
# 25  contato@moniqueevelle.com.br
# 26                           NaN
# 27                           NaN
# 28                           NaN
# 29                           NaN
#
#                                               Company  \
# 0                                       Confidential
# 1                                         QuintoAndar
# 2                                          Neoenergia
# 3                                               iFood
# 4                                             ItauBBA
# 5   CNPq - Conselho Nacional de Desenvolvimento Ci...
# 6                                            One4 Srl
# 7                                Inconsistent Systems
# 8                                       MBA USP/Esalq
# 9                                                 NaN
# 10          FRST - Falconi Road of Skills and Talents
# 11                                                NaN
# 12                                              iFood
# 13                                            Hashdex
# 14                             Ministério da Economia
# 15                                         banco next
# 16                    Banco do Nordeste do Brasil S.A
# 17                                      Itaú Unibanco
# 18  Confederação da Agricultura e Pecuária do Bras...
# 19                                      MBA USP/Esalq
# 20                  SOLINFTEC - Automação Sem Limites
# 21                                                 RD
# 22                                 Sebrae Mato Grosso
# 23                                             HiMama
# 24                                Isée dataSTRATEGIES
# 25                                         Inventivos
# 26                                     Allianz Brasil
# 27                                               Vale
# 28                                FIA Business School
# 29                                        PwC Finland
#
#                                              Position Connected On  My Network
# 0                                   Reporting Manager  13 May 2021  My Network
# 1                             Data Privacy Specialist  13 May 2021  My Network
# 2    Analista de Manutenção de Redes e Subtransmissão  12 May 2021  My Network
# 3                              Data Analyst (Product)  12 May 2021  My Network
# 4                                 Lead Data Scientist  11 May 2021  My Network
# 5                                           Bolsista   11 May 2021  My Network
# 6       Full Stack Developer - Intesi Group / Edenred  10 May 2021  My Network
# 7                                                 Dev  10 May 2021  My Network
# 8                  Estudante de MBA em tempo integral  09 May 2021  My Network
# 9                                                 NaN          NaN  My Network
# 10                                  Mentoring Manager  06 May 2021  My Network
# 11                                                NaN          NaN  My Network
# 12                  Data Analytics Manager - Consumer  05 May 2021  My Network
# 13                                  Portfolio Manager  05 May 2021  My Network
# 14        Coordenador-Geral de Inteligência Econômica  03 May 2021  My Network
# 15                                Lead Data Scientist  01 May 2021  My Network
# 16                                    Chief Economist  30 Apr 2021  My Network
# 17                                  Data Scientist II  28 Apr 2021  My Network
# 18                    Coordenação do Núcleo Econômico  28 Apr 2021  My Network
# 19                             Data Science Professor  28 Apr 2021  My Network
# 20                           Research And Development  27 Apr 2021  My Network
# 21                        Gerente de Ciência de Dados  27 Apr 2021  My Network
# 22                                          Analista   26 Apr 2021  My Network
# 23        Accounts Receivable and Payments Specialist  26 Apr 2021  My Network
# 24                                    Conseil en data  23 Apr 2021  My Network
# 25                                        Cofundadora  23 Apr 2021  My Network
# 26  Chief Data and Analytics Officer - Executive D...  22 Apr 2021  My Network
# 27                               Analista operacional  20 Apr 2021  My Network
# 28                         Membro do Conselho Curador  20 Apr 2021  My Network
# 29                      Chief Data Scientist/Director  19 Apr 2021  My Network

# %%
key = "42118bd8f1404049b672526a9681a946"
endpoint = "https://reconhecimentolinkedin.cognitiveservices.azure.com/"

# %%
from azure.ai.textanalytics import TextAnalyticsClient
from azure.core.credentials import AzureKeyCredential

def authenticate_client():
    ta_credential = AzureKeyCredential(key)
    text_analytics_client = TextAnalyticsClient(
            endpoint=endpoint, 
            credential=ta_credential)
    return text_analytics_client

client = authenticate_client()

# %%
    try:
        documents = ["Conseil en data"]

        response = client.extract_key_phrases(documents = documents)[0]

        if not response.is_error:
            print("\tKey Phrases:")
            for phrase in response.key_phrases:
                print("\t\t", phrase)
        else:
            print(response.id, response.error)

    except Exception as err:
        print("Encountered exception. {}".format(err))
# Out:
# 	Key Phrases:
# 		 Conseil en data

# %%
    try:
        documents = ["Itaú Unibanco"]
        result = client.recognize_linked_entities(documents = documents)[0]

        print("Linked Entities:\n")
        for entity in result.entities:
            print("\tName: ", entity.name, "\tId: ", entity.data_source_entity_id, "\tUrl: ", entity.url,
            "\n\tData Source: ", entity.data_source)
            print("\tMatches:")
            for match in entity.matches:
                print("\t\tText:", match.text)
                print("\t\tConfidence Score: {0:.2f}".format(match.confidence_score))
                print("\t\tOffset: {}".format(match.offset))
                print("\t\tLength: {}".format(match.length))
            
    except Exception as err:
        print("Encountered exception. {}".format(err))
# Out:
# Linked Entities:
#
# 	Name:  Itaú Unibanco 	Id:  Itaú Unibanco 	Url:  https://en.wikipedia.org/wiki/Itaú_Unibanco
# 	Data Source:  Wikipedia
# 	Matches:
# 		Text: Itaú Unibanco
# 		Confidence Score: 0.78
# 		Offset: 0
# 		Length: 13
